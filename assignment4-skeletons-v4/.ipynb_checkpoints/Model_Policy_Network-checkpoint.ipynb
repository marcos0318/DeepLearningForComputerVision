# %% [markdown]
# # Model-Based RL
# In this exercise you will implement a policy and model network which work in tandem to solve the CartPole reinforcement learning problem.

# %% [markdown]
# What is a model and why would we want to use one? In this case, a model is going to be a neural network that attempts to learn the dynamics of the real environment. For example, in the CartPole we would like a model to be able to predict the next position of the Cart given the previous position and an action. By learning an accurate model, we can train our agent using the model rather than requiring to use the real environment every time. While this may seem less useful when the real environment is itself a simulation, like in our CartPole task, it can have huge advantages when attempting to learn policies for acting in the physical world.

# %% [markdown]
# How are we going to accomplish this in Tensorflow? We are going to be using a neural network that will learn the transition dynamics between a previous observation and action, and the expected new observation, reward, and done state. Our training procedure will involve switching between training our model using the real environment, and training our agent’s policy using the model environment. By using this approach we will be able to learn a policy that allows our agent to solve the CartPole task without actually ever training the policy on the real environment!

# %% [markdown]
# ### Loading libraries and starting CartPole environment

# %%
from __future__ import print_function
import numpy as np
try:
    import cPickle as pickle
except:
    import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math
# Out:
# C:\Users\BaiJiaxin\Anaconda2\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import sys
if sys.version_info.major > 2:
    xrange = range
del sys

# %%
import gym
env = gym.make('CartPole-v0')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %% [markdown]
# ### Setting Hyper-parameters

# %%
# hyperparameters
H = 8 # number of hidden layer neurons
learning_rate = 1e-2
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = False # resume from previous checkpoint?

model_bs = 3 # Batch size when learning from model
real_bs = 3 # Batch size when learning from real environment

# model initialization
D = 4 # input dimensionality

# %% [markdown]
# ### Policy Network

# %%
tf.reset_default_graph()
observations = tf.placeholder(tf.float32, [None,4] , name="input_x")
W1 = tf.get_variable("W1", shape=[4, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")
adam = tf.train.AdamOptimizer(learning_rate=learning_rate)
W1Grad = tf.placeholder(tf.float32,name="batch_grad1")
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]

################################################################################
# TODO: Implement the loss function.                                           #
# This sends the weights in the direction of making actions that gave good     #
# advantage (reward overtime) more likely, and actions that didn't less likely.#
################################################################################
_log = tf.log(input_y * (input_y - probability) + (1 - input_y) * (input_y + probability))  # think
loss = -tf.reduce_mean(advantages * _log) 
################################################################################
#                                 END OF YOUR CODE                             #
################################################################################

newGrads = tf.gradients(loss,tvars)
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))
# Out:
# WARNING:tensorflow:From C:\Users\BaiJiaxin\Anaconda2\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %% [markdown]
# ### Model Network
# Here we implement a multi-layer neural network that predicts the next observation, reward, and done state from a current state and action.

# %%
mH = 256 # model layer size

input_data = tf.placeholder(tf.float32, [None, 5])
with tf.variable_scope('rnnlm'):
    softmax_w = tf.get_variable("softmax_w", [mH, 50])
    softmax_b = tf.get_variable("softmax_b", [50])

previous_state = tf.placeholder(tf.float32, [None,5] , name="previous_state")
W1M = tf.get_variable("W1M", shape=[5, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B1M = tf.Variable(tf.zeros([mH]),name="B1M")
layer1M = tf.nn.relu(tf.matmul(previous_state,W1M) + B1M)
W2M = tf.get_variable("W2M", shape=[mH, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B2M = tf.Variable(tf.zeros([mH]),name="B2M")
layer2M = tf.nn.relu(tf.matmul(layer1M,W2M) + B2M)
wO = tf.get_variable("wO", shape=[mH, 4],
           initializer=tf.contrib.layers.xavier_initializer())
wR = tf.get_variable("wR", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())
wD = tf.get_variable("wD", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())

bO = tf.Variable(tf.zeros([4]),name="bO")
bR = tf.Variable(tf.zeros([1]),name="bR")
bD = tf.Variable(tf.ones([1]),name="bD")


predicted_observation = tf.matmul(layer2M,wO,name="predicted_observation") + bO
predicted_reward = tf.matmul(layer2M,wR,name="predicted_reward") + bR
predicted_done = tf.sigmoid(tf.matmul(layer2M,wD,name="predicted_done") + bD)

true_observation = tf.placeholder(tf.float32,[None,4],name="true_observation")
true_reward = tf.placeholder(tf.float32,[None,1],name="true_reward")
true_done = tf.placeholder(tf.float32,[None,1],name="true_done")


predicted_state = tf.concat([predicted_observation,predicted_reward,predicted_done],1)

observation_loss = tf.square(true_observation - predicted_observation)

reward_loss = tf.square(true_reward - predicted_reward)

done_loss = tf.multiply(predicted_done, true_done) + tf.multiply(1-predicted_done, 1-true_done)
done_loss = -tf.log(done_loss)

model_loss = tf.reduce_mean(observation_loss + done_loss + reward_loss)

modelAdam = tf.train.AdamOptimizer(learning_rate=learning_rate)
updateModel = modelAdam.minimize(model_loss)

# %% [markdown]
# ### Helper-functions

# %%
def resetGradBuffer(gradBuffer):
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    return gradBuffer

def discount_rewards(r):
    ################################################################################
    # TODO: Implement the discounted rewards function                              #
    # Return discounted rewards weighed by gamma. Each reward will be replaced     #
    # with a weight reward that involves itself and all the other rewards occuring #
    # after it. The later the reward after it happens, the less effect it has on   #
    # the current rewards's discounted reward                                      #
    # Hint: [r0, r1, r2, ..., r_N] will look someting like:                        #
    #       [(r0 + r1*gamma^1 + ... r_N*gamma^N), (r1 + r2*gamma^1 + ...), ...]    #
    ################################################################################
    discounted_r = np.zeros_like(r)
    running_add = 0
    for t in reversed(range(0, r.size)):
        running_add = running_add * gamma + r[t]
        discounted_r[t] = running_add
    return discounted_r     
    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################

# This function uses our model to produce a new state when given a previous state and action
def stepModel(sess, xs, action):
    toFeed = np.reshape(np.hstack([xs[-1][0],np.array(action)]),[1,5])
    myPredict = sess.run([predicted_state],feed_dict={previous_state: toFeed})
    reward = myPredict[0][:,4]
    observation = myPredict[0][:,0:4]
    observation[:,0] = np.clip(observation[:,0],-2.4,2.4)
    observation[:,2] = np.clip(observation[:,2],-0.4,0.4)
    doneP = np.clip(myPredict[0][:,5],0,1)
    if doneP > 0.1 or len(xs)>= 300:
        done = True
    else:
        done = False
    return observation, reward, done

# %% [markdown]
# ## Training the Policy and Model

# %%
xs,drs,ys,ds = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
real_episodes = 1
init = tf.global_variables_initializer()
batch_size = real_bs

drawFromModel = False # When set to True, will use model for observations
trainTheModel = True # Whether to train the model
trainThePolicy = False # Whether to train the policy
switch_point = 1

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset()
    x = observation
    gradBuffer = sess.run(tvars)
    gradBuffer = resetGradBuffer(gradBuffer)
    
    while episode_number <= 5000:
        # Start displaying environment once performance is acceptably high.
        if (reward_sum/batch_size > 150 and drawFromModel == False) or rendering == True : 
            env.render()
            rendering = True
            
        x = np.reshape(observation,[1,4])

        tfprob = sess.run(probability,feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0

        # record various intermediates (needed later for backprop)
        xs.append(x) 
        y = 1 if action == 0 else 0 
        ys.append(y)
        
        # step the  model or real environment and get new measurements
        if drawFromModel == False:
            observation, reward, done, info = env.step(action)
        else:
            observation, reward, done = stepModel(sess,xs,action)
                
        reward_sum += reward
        
        ds.append(done*1)
        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            
            if drawFromModel == False: 
                real_episodes += 1
            episode_number += 1

            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            epd = np.vstack(ds)
            xs,drs,ys,ds = [],[],[],[] # reset array memory
            
            if trainTheModel == True:
                
                ################################################################################
                # TODO: Run the model network and compute predicted_state                      #
                # Output: 'pState'                                                             #
                ################################################################################
                actions = np.array([np.abs(y-1) for y in epy][:-1])
                state_prevs = np.hstack([epx[:-1,:], actions])
                state_nexts = epx[1:,:]
                rewards = np.array(epr[1:,:])
                dones = np.array(epd[1:,:])
                state_nextsAll = np.hstack([state_nexts, rewards, dones])

                feed_dict={previous_state: state_prevs, true_observation: state_nexts,true_done:dones, true_reward:rewards}
                loss, pState, _ = sess.run([model_loss, predicted_state, updateModel], feed_dict)
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                

            if trainThePolicy == True:
                
                ################################################################################
                # TODO: Run the policy network and compute newGrads                            #
                # Output: 'tGrad'                                                              #
                ################################################################################
                discounted_epr = discount_rewards(epr).astype('float32')
                discounted_epr -= np.mean(discounted_epr)
                discounted_epr /= np.std(discounted_epr)
                feed_dict = {observations: epx, input_y: epy, advantages: discounted_epr}
                tGrad = sess.run(newGrads,feed_dict = feed_dict)
 
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                
                # If gradients becom too large, end training process
                if np.sum(tGrad[0] == tGrad[0]) == 0:
                    break
                for ix,grad in enumerate(tGrad):
                    gradBuffer[ix] += grad
                
            if switch_point + batch_size == episode_number: 
                switch_point = episode_number
                if trainThePolicy == True:
                    
                    ################################################################################
                    # TODO:                                                                        #
                    # (1) Run the policy network and update gradients                              #
                    # (2) Reset gradBuffer to 0                                                    #
                    ################################################################################
                    sess.run(updateGrads, feed_dict={W1Grad: gradBuffer[0], W2Grad:gradBuffer[1]})
                    gradBuffer = resetGradBuffer(gradBuffer)                   
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################

                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                if drawFromModel == False:
                    print('World Perf: Episode %f. Reward %f. action: %f. mean reward %f.' % (real_episodes,reward_sum/real_bs,action, running_reward/real_bs))
                    if reward_sum/batch_size > 200:
                        break
                reward_sum = 0

                # Once the model has been trained on 100 episodes
                if episode_number > 100:
                    
                    ################################################################################
                    # TODO: Alternating between training the policy from the model and training    #
                    # the model from the real environment.                                         #
                    ################################################################################
                    drawFromModel = not drawFromModel
                    trainTheModel = not trainTheModel
                    trainThePolicy = not trainThePolicy
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################
            
            if drawFromModel == True:
                observation = np.random.uniform(-0.1,0.1,[4]) # Generate reasonable starting point
                batch_size = model_bs
            else:
                observation = env.reset()
                batch_size = real_bs
                
print(real_episodes)
# Out:
# World Perf: Episode 4.000000. Reward 22.000000. action: 0.000000. mean reward 22.000000.
# World Perf: Episode 7.000000. Reward 26.000000. action: 0.000000. mean reward 22.040000.
# World Perf: Episode 10.000000. Reward 22.666667. action: 0.000000. mean reward 22.046267.
# World Perf: Episode 13.000000. Reward 14.000000. action: 0.000000. mean reward 21.965804.
# World Perf: Episode 16.000000. Reward 32.333333. action: 0.000000. mean reward 22.069479.
# World Perf: Episode 19.000000. Reward 36.000000. action: 0.000000. mean reward 22.208785.
# World Perf: Episode 22.000000. Reward 13.000000. action: 0.000000. mean reward 22.116697.
# World Perf: Episode 25.000000. Reward 22.333333. action: 0.000000. mean reward 22.118863.
# World Perf: Episode 28.000000. Reward 13.333333. action: 0.000000. mean reward 22.031008.
# World Perf: Episode 31.000000. Reward 23.333333. action: 0.000000. mean reward 22.044031.
# World Perf: Episode 34.000000. Reward 15.000000. action: 1.000000. mean reward 21.973591.
# World Perf: Episode 37.000000. Reward 19.333333. action: 0.000000. mean reward 21.947188.
# World Perf: Episode 40.000000. Reward 18.666667. action: 1.000000. mean reward 21.914383.
# World Perf: Episode 43.000000. Reward 31.666667. action: 0.000000. mean reward 22.011906.
# World Perf: Episode 46.000000. Reward 32.666667. action: 0.000000. mean reward 22.118453.
# World Perf: Episode 49.000000. Reward 20.333333. action: 0.000000. mean reward 22.100602.
# World Perf: Episode 52.000000. Reward 29.000000. action: 0.000000. mean reward 22.169596.
# World Perf: Episode 55.000000. Reward 21.333333. action: 1.000000. mean reward 22.161233.
# World Perf: Episode 58.000000. Reward 22.666667. action: 1.000000. mean reward 22.166288.
# World Perf: Episode 61.000000. Reward 15.666667. action: 0.000000. mean reward 22.101292.
# World Perf: Episode 64.000000. Reward 31.666667. action: 1.000000. mean reward 22.196945.
# World Perf: Episode 67.000000. Reward 34.666667. action: 0.000000. mean reward 22.321643.
# World Perf: Episode 70.000000. Reward 18.000000. action: 0.000000. mean reward 22.278426.
# World Perf: Episode 73.000000. Reward 19.666667. action: 1.000000. mean reward 22.252309.
# World Perf: Episode 76.000000. Reward 27.000000. action: 0.000000. mean reward 22.299785.
# World Perf: Episode 79.000000. Reward 22.000000. action: 0.000000. mean reward 22.296788.
# World Perf: Episode 82.000000. Reward 21.666667. action: 0.000000. mean reward 22.290486.
# World Perf: Episode 85.000000. Reward 24.000000. action: 0.000000. mean reward 22.307582.
# World Perf: Episode 88.000000. Reward 32.666667. action: 0.000000. mean reward 22.411172.
# World Perf: Episode 91.000000. Reward 21.666667. action: 0.000000. mean reward 22.403727.
# World Perf: Episode 94.000000. Reward 50.000000. action: 0.000000. mean reward 22.679690.
# World Perf: Episode 97.000000. Reward 23.666667. action: 0.000000. mean reward 22.689560.
# World Perf: Episode 100.000000. Reward 26.666667. action: 0.000000. mean reward 22.729331.
# World Perf: Episode 103.000000. Reward 34.000000. action: 1.000000. mean reward 22.842038.
# World Perf: Episode 106.000000. Reward 24.333333. action: 1.000000. mean reward 22.980696.
# World Perf: Episode 109.000000. Reward 24.666667. action: 0.000000. mean reward 23.156427.
# World Perf: Episode 112.000000. Reward 23.333333. action: 0.000000. mean reward 23.267509.
# World Perf: Episode 115.000000. Reward 28.000000. action: 1.000000. mean reward 23.203039.
# World Perf: Episode 118.000000. Reward 17.666667. action: 1.000000. mean reward 22.980005.
# World Perf: Episode 121.000000. Reward 34.000000. action: 1.000000. mean reward 23.585432.
# World Perf: Episode 124.000000. Reward 18.666667. action: 1.000000. mean reward 23.439306.
# World Perf: Episode 127.000000. Reward 39.000000. action: 0.000000. mean reward 23.451342.
# World Perf: Episode 130.000000. Reward 11.333333. action: 1.000000. mean reward 23.261419.
# World Perf: Episode 133.000000. Reward 40.666667. action: 0.000000. mean reward 24.391100.
# World Perf: Episode 136.000000. Reward 23.000000. action: 0.000000. mean reward 24.268248.
# World Perf: Episode 139.000000. Reward 24.666667. action: 0.000000. mean reward 24.220291.
# World Perf: Episode 142.000000. Reward 30.666667. action: 1.000000. mean reward 24.110529.
# World Perf: Episode 145.000000. Reward 30.333333. action: 0.000000. mean reward 26.960754.
# World Perf: Episode 148.000000. Reward 29.000000. action: 0.000000. mean reward 26.898069.
# World Perf: Episode 151.000000. Reward 29.333333. action: 0.000000. mean reward 26.804876.
# World Perf: Episode 154.000000. Reward 15.000000. action: 0.000000. mean reward 26.512987.
# World Perf: Episode 157.000000. Reward 27.000000. action: 0.000000. mean reward 26.310175.
# World Perf: Episode 160.000000. Reward 35.666667. action: 1.000000. mean reward 26.196020.
# World Perf: Episode 163.000000. Reward 13.333333. action: 0.000000. mean reward 26.540327.
# World Perf: Episode 166.000000. Reward 32.333333. action: 0.000000. mean reward 26.412016.
# World Perf: Episode 169.000000. Reward 49.666667. action: 1.000000. mean reward 26.517118.
# World Perf: Episode 172.000000. Reward 44.000000. action: 1.000000. mean reward 26.808138.
# World Perf: Episode 175.000000. Reward 43.666667. action: 0.000000. mean reward 26.869942.
# World Perf: Episode 178.000000. Reward 25.333333. action: 0.000000. mean reward 26.940529.
# World Perf: Episode 181.000000. Reward 68.666667. action: 0.000000. mean reward 27.288465.
# World Perf: Episode 184.000000. Reward 32.000000. action: 1.000000. mean reward 27.206772.
# World Perf: Episode 187.000000. Reward 31.333333. action: 1.000000. mean reward 27.388460.
# World Perf: Episode 190.000000. Reward 41.000000. action: 1.000000. mean reward 29.706129.
# World Perf: Episode 193.000000. Reward 46.000000. action: 1.000000. mean reward 30.225718.
# World Perf: Episode 196.000000. Reward 42.333333. action: 0.000000. mean reward 30.305349.
# World Perf: Episode 199.000000. Reward 27.333333. action: 1.000000. mean reward 30.214170.
# World Perf: Episode 202.000000. Reward 19.333333. action: 1.000000. mean reward 30.003984.
# World Perf: Episode 205.000000. Reward 38.000000. action: 0.000000. mean reward 29.907461.
# World Perf: Episode 208.000000. Reward 43.666667. action: 0.000000. mean reward 29.802134.
# World Perf: Episode 211.000000. Reward 39.333333. action: 1.000000. mean reward 29.719170.
# World Perf: Episode 214.000000. Reward 17.000000. action: 1.000000. mean reward 29.483116.
# World Perf: Episode 217.000000. Reward 42.000000. action: 1.000000. mean reward 29.495317.
# World Perf: Episode 220.000000. Reward 31.000000. action: 1.000000. mean reward 29.538254.
# World Perf: Episode 223.000000. Reward 36.666667. action: 0.000000. mean reward 29.456057.
# World Perf: Episode 226.000000. Reward 37.333333. action: 0.000000. mean reward 29.505112.
# World Perf: Episode 229.000000. Reward 35.333333. action: 1.000000. mean reward 29.529955.
# World Perf: Episode 232.000000. Reward 46.000000. action: 1.000000. mean reward 29.658737.
# World Perf: Episode 235.000000. Reward 62.333333. action: 0.000000. mean reward 30.002069.
# World Perf: Episode 238.000000. Reward 63.333333. action: 1.000000. mean reward 30.082140.
# World Perf: Episode 241.000000. Reward 30.000000. action: 0.000000. mean reward 29.926275.
# World Perf: Episode 244.000000. Reward 35.333333. action: 1.000000. mean reward 29.898674.
# World Perf: Episode 247.000000. Reward 20.333333. action: 0.000000. mean reward 29.610746.
# World Perf: Episode 250.000000. Reward 26.333333. action: 0.000000. mean reward 29.655960.
# World Perf: Episode 253.000000. Reward 27.333333. action: 1.000000. mean reward 29.696815.
# World Perf: Episode 256.000000. Reward 48.000000. action: 1.000000. mean reward 29.686630.
# World Perf: Episode 259.000000. Reward 31.333333. action: 1.000000. mean reward 29.943998.
# World Perf: Episode 262.000000. Reward 61.000000. action: 0.000000. mean reward 30.382231.
# World Perf: Episode 265.000000. Reward 21.666667. action: 1.000000. mean reward 30.152061.
# World Perf: Episode 268.000000. Reward 41.666667. action: 1.000000. mean reward 30.148476.
# World Perf: Episode 271.000000. Reward 26.000000. action: 1.000000. mean reward 30.029383.
# World Perf: Episode 274.000000. Reward 79.666667. action: 1.000000. mean reward 30.347672.
# World Perf: Episode 277.000000. Reward 58.333333. action: 0.000000. mean reward 30.531996.
# World Perf: Episode 280.000000. Reward 25.666667. action: 0.000000. mean reward 30.661011.
# World Perf: Episode 283.000000. Reward 39.333333. action: 1.000000. mean reward 30.619677.
# World Perf: Episode 286.000000. Reward 23.666667. action: 1.000000. mean reward 31.402878.
# World Perf: Episode 289.000000. Reward 41.666667. action: 0.000000. mean reward 31.318003.
# World Perf: Episode 292.000000. Reward 72.666667. action: 0.000000. mean reward 31.557268.
# World Perf: Episode 295.000000. Reward 42.666667. action: 0.000000. mean reward 33.666122.
# World Perf: Episode 298.000000. Reward 23.000000. action: 1.000000. mean reward 35.935959.
# World Perf: Episode 301.000000. Reward 56.333333. action: 1.000000. mean reward 35.844280.
# World Perf: Episode 304.000000. Reward 62.333333. action: 0.000000. mean reward 36.614109.
# World Perf: Episode 307.000000. Reward 43.666667. action: 0.000000. mean reward 36.412506.
# World Perf: Episode 310.000000. Reward 66.666667. action: 1.000000. mean reward 36.451195.
# World Perf: Episode 313.000000. Reward 51.333333. action: 0.000000. mean reward 36.342579.
# World Perf: Episode 316.000000. Reward 30.333333. action: 0.000000. mean reward 35.994724.
# World Perf: Episode 319.000000. Reward 22.333333. action: 1.000000. mean reward 35.657837.
# World Perf: Episode 322.000000. Reward 48.666667. action: 1.000000. mean reward 35.563137.
# World Perf: Episode 325.000000. Reward 34.666667. action: 0.000000. mean reward 35.275661.
# World Perf: Episode 328.000000. Reward 27.000000. action: 1.000000. mean reward 34.898739.
# World Perf: Episode 331.000000. Reward 57.666667. action: 1.000000. mean reward 34.864857.
# World Perf: Episode 334.000000. Reward 37.333333. action: 1.000000. mean reward 34.966564.
# World Perf: Episode 337.000000. Reward 60.666667. action: 0.000000. mean reward 37.572769.
# World Perf: Episode 340.000000. Reward 51.666667. action: 0.000000. mean reward 39.950970.
# World Perf: Episode 343.000000. Reward 58.333333. action: 1.000000. mean reward 42.607296.
# World Perf: Episode 346.000000. Reward 81.333333. action: 1.000000. mean reward 45.325390.
# World Perf: Episode 349.000000. Reward 70.666667. action: 0.000000. mean reward 45.220963.
# World Perf: Episode 352.000000. Reward 30.333333. action: 1.000000. mean reward 44.704525.
# World Perf: Episode 355.000000. Reward 32.333333. action: 1.000000. mean reward 44.260437.
# World Perf: Episode 358.000000. Reward 32.000000. action: 0.000000. mean reward 43.803150.
# World Perf: Episode 361.000000. Reward 61.000000. action: 1.000000. mean reward 43.615189.
# World Perf: Episode 364.000000. Reward 44.333333. action: 1.000000. mean reward 43.297241.
# World Perf: Episode 367.000000. Reward 61.000000. action: 1.000000. mean reward 43.152344.
# World Perf: Episode 370.000000. Reward 57.333333. action: 1.000000. mean reward 43.059032.
# World Perf: Episode 373.000000. Reward 71.000000. action: 1.000000. mean reward 45.288799.
# World Perf: Episode 376.000000. Reward 52.000000. action: 1.000000. mean reward 45.041676.
# World Perf: Episode 379.000000. Reward 80.666667. action: 0.000000. mean reward 45.077271.
# World Perf: Episode 382.000000. Reward 36.000000. action: 1.000000. mean reward 44.618576.
# World Perf: Episode 385.000000. Reward 37.666667. action: 0.000000. mean reward 47.169800.
# World Perf: Episode 388.000000. Reward 73.333333. action: 1.000000. mean reward 47.180908.
# World Perf: Episode 391.000000. Reward 50.000000. action: 0.000000. mean reward 47.498463.
# World Perf: Episode 394.000000. Reward 56.000000. action: 1.000000. mean reward 47.254181.
# World Perf: Episode 397.000000. Reward 72.333333. action: 1.000000. mean reward 47.135769.
# World Perf: Episode 400.000000. Reward 36.666667. action: 1.000000. mean reward 47.392094.
# World Perf: Episode 403.000000. Reward 24.000000. action: 1.000000. mean reward 46.907627.
# World Perf: Episode 406.000000. Reward 109.333333. action: 0.000000. mean reward 47.164433.
# World Perf: Episode 409.000000. Reward 57.333333. action: 1.000000. mean reward 46.950787.
# World Perf: Episode 412.000000. Reward 69.333333. action: 0.000000. mean reward 46.813335.
# World Perf: Episode 415.000000. Reward 53.000000. action: 0.000000. mean reward 46.569546.
# World Perf: Episode 418.000000. Reward 78.333333. action: 1.000000. mean reward 46.569584.
# World Perf: Episode 421.000000. Reward 80.333333. action: 0.000000. mean reward 46.539005.
# World Perf: Episode 424.000000. Reward 100.333333. action: 0.000000. mean reward 46.996246.
# World Perf: Episode 427.000000. Reward 40.000000. action: 0.000000. mean reward 47.316315.
# World Perf: Episode 430.000000. Reward 67.000000. action: 0.000000. mean reward 47.137695.
# World Perf: Episode 433.000000. Reward 69.000000. action: 1.000000. mean reward 46.986759.
# World Perf: Episode 436.000000. Reward 69.666667. action: 1.000000. mean reward 47.395599.
# World Perf: Episode 439.000000. Reward 52.666667. action: 1.000000. mean reward 47.042267.
# World Perf: Episode 442.000000. Reward 47.000000. action: 0.000000. mean reward 49.657055.
# World Perf: Episode 445.000000. Reward 58.666667. action: 1.000000. mean reward 49.534077.
# World Perf: Episode 448.000000. Reward 63.666667. action: 1.000000. mean reward 49.291180.
# World Perf: Episode 451.000000. Reward 53.333333. action: 0.000000. mean reward 49.102596.
# World Perf: Episode 454.000000. Reward 95.333333. action: 1.000000. mean reward 49.225952.
# World Perf: Episode 457.000000. Reward 59.000000. action: 0.000000. mean reward 49.384411.
# World Perf: Episode 460.000000. Reward 57.333333. action: 1.000000. mean reward 49.256992.
# World Perf: Episode 463.000000. Reward 55.333333. action: 0.000000. mean reward 50.346012.
# World Perf: Episode 466.000000. Reward 91.333333. action: 1.000000. mean reward 53.309631.
# World Perf: Episode 469.000000. Reward 63.666667. action: 0.000000. mean reward 54.018642.
# World Perf: Episode 472.000000. Reward 154.666667. action: 0.000000. mean reward 54.569660.
# World Perf: Episode 475.000000. Reward 50.666667. action: 0.000000. mean reward 54.093227.
# World Perf: Episode 478.000000. Reward 108.000000. action: 0.000000. mean reward 54.148956.
# World Perf: Episode 481.000000. Reward 106.000000. action: 0.000000. mean reward 54.167492.
# World Perf: Episode 484.000000. Reward 67.000000. action: 0.000000. mean reward 53.833096.
# World Perf: Episode 487.000000. Reward 90.333333. action: 1.000000. mean reward 53.802113.
# World Perf: Episode 490.000000. Reward 59.000000. action: 0.000000. mean reward 53.365231.
# World Perf: Episode 493.000000. Reward 77.666667. action: 1.000000. mean reward 53.165638.
# World Perf: Episode 496.000000. Reward 107.000000. action: 1.000000. mean reward 53.323582.
# World Perf: Episode 499.000000. Reward 64.000000. action: 1.000000. mean reward 52.992161.
# World Perf: Episode 502.000000. Reward 41.000000. action: 1.000000. mean reward 52.409901.
# World Perf: Episode 505.000000. Reward 49.333333. action: 1.000000. mean reward 52.953259.
# World Perf: Episode 508.000000. Reward 73.333333. action: 1.000000. mean reward 52.734329.
# World Perf: Episode 511.000000. Reward 67.333333. action: 0.000000. mean reward 52.421070.
# World Perf: Episode 514.000000. Reward 54.333333. action: 1.000000. mean reward 53.932034.
# World Perf: Episode 517.000000. Reward 81.000000. action: 0.000000. mean reward 56.595520.
# World Perf: Episode 520.000000. Reward 46.000000. action: 1.000000. mean reward 58.902287.
# World Perf: Episode 523.000000. Reward 68.666667. action: 0.000000. mean reward 58.643963.
# World Perf: Episode 526.000000. Reward 46.333333. action: 1.000000. mean reward 59.592987.
# World Perf: Episode 529.000000. Reward 91.666667. action: 0.000000. mean reward 62.244022.
# World Perf: Episode 532.000000. Reward 141.666667. action: 0.000000. mean reward 62.615681.
# World Perf: Episode 535.000000. Reward 142.333333. action: 0.000000. mean reward 64.060822.
# World Perf: Episode 538.000000. Reward 137.333333. action: 1.000000. mean reward 64.850060.
# World Perf: Episode 541.000000. Reward 86.000000. action: 1.000000. mean reward 64.533112.
# World Perf: Episode 544.000000. Reward 25.666667. action: 1.000000. mean reward 63.767193.
# World Perf: Episode 547.000000. Reward 135.000000. action: 1.000000. mean reward 64.092003.
# World Perf: Episode 550.000000. Reward 35.666667. action: 1.000000. mean reward 63.379124.
# World Perf: Episode 553.000000. Reward 69.666667. action: 0.000000. mean reward 66.267967.
# World Perf: Episode 556.000000. Reward 77.333333. action: 0.000000. mean reward 66.026833.
# World Perf: Episode 559.000000. Reward 62.000000. action: 0.000000. mean reward 67.971863.
# World Perf: Episode 562.000000. Reward 105.000000. action: 0.000000. mean reward 73.903610.
# World Perf: Episode 565.000000. Reward 93.666667. action: 1.000000. mean reward 73.592461.
# World Perf: Episode 568.000000. Reward 148.333333. action: 0.000000. mean reward 77.177162.
# World Perf: Episode 571.000000. Reward 66.000000. action: 1.000000. mean reward 76.361580.
# World Perf: Episode 574.000000. Reward 91.333333. action: 0.000000. mean reward 75.806816.
# World Perf: Episode 577.000000. Reward 80.333333. action: 1.000000. mean reward 78.275322.
# World Perf: Episode 580.000000. Reward 105.000000. action: 1.000000. mean reward 77.905594.
# World Perf: Episode 583.000000. Reward 71.333333. action: 0.000000. mean reward 77.206673.
# World Perf: Episode 586.000000. Reward 128.666667. action: 1.000000. mean reward 77.332596.
# World Perf: Episode 589.000000. Reward 102.000000. action: 1.000000. mean reward 76.997719.
# World Perf: Episode 592.000000. Reward 76.666667. action: 1.000000. mean reward 76.468216.
# World Perf: Episode 595.000000. Reward 55.000000. action: 0.000000. mean reward 75.634453.
# World Perf: Episode 598.000000. Reward 72.333333. action: 0.000000. mean reward 75.017006.
# World Perf: Episode 601.000000. Reward 64.333333. action: 1.000000. mean reward 74.569366.
# World Perf: Episode 604.000000. Reward 86.333333. action: 1.000000. mean reward 74.267517.
# World Perf: Episode 607.000000. Reward 79.000000. action: 1.000000. mean reward 73.848434.
# World Perf: Episode 610.000000. Reward 86.000000. action: 0.000000. mean reward 80.748169.
# World Perf: Episode 613.000000. Reward 53.333333. action: 1.000000. mean reward 79.746590.
# World Perf: Episode 616.000000. Reward 49.666667. action: 1.000000. mean reward 78.900208.
# World Perf: Episode 619.000000. Reward 94.333333. action: 1.000000. mean reward 81.275169.
# World Perf: Episode 622.000000. Reward 196.333333. action: 0.000000. mean reward 84.591644.
# World Perf: Episode 625.000000. Reward 162.333333. action: 0.000000. mean reward 87.418053.
# World Perf: Episode 628.000000. Reward 123.333333. action: 1.000000. mean reward 87.050964.
# World Perf: Episode 631.000000. Reward 64.000000. action: 0.000000. mean reward 86.036133.
# World Perf: Episode 634.000000. Reward 119.666667. action: 0.000000. mean reward 86.400032.
# World Perf: Episode 637.000000. Reward 70.000000. action: 1.000000. mean reward 85.419151.
# World Perf: Episode 640.000000. Reward 121.666667. action: 0.000000. mean reward 85.187080.
# World Perf: Episode 643.000000. Reward 87.333333. action: 0.000000. mean reward 84.408623.
# World Perf: Episode 646.000000. Reward 76.666667. action: 0.000000. mean reward 86.515877.
# World Perf: Episode 649.000000. Reward 160.000000. action: 0.000000. mean reward 89.574257.
# World Perf: Episode 652.000000. Reward 95.666667. action: 0.000000. mean reward 90.849434.
# World Perf: Episode 655.000000. Reward 63.666667. action: 1.000000. mean reward 92.740540.
# World Perf: Episode 658.000000. Reward 115.333333. action: 1.000000. mean reward 94.921700.
# World Perf: Episode 661.000000. Reward 67.666667. action: 0.000000. mean reward 94.079735.
# World Perf: Episode 664.000000. Reward 102.333333. action: 1.000000. mean reward 94.055916.
# World Perf: Episode 667.000000. Reward 78.333333. action: 1.000000. mean reward 93.717461.
# World Perf: Episode 670.000000. Reward 130.333333. action: 0.000000. mean reward 93.233421.
# World Perf: Episode 673.000000. Reward 80.000000. action: 0.000000. mean reward 92.293182.
# World Perf: Episode 676.000000. Reward 119.333333. action: 0.000000. mean reward 91.874077.
# World Perf: Episode 679.000000. Reward 154.666667. action: 0.000000. mean reward 92.891838.
# World Perf: Episode 682.000000. Reward 178.666667. action: 0.000000. mean reward 93.132027.
# World Perf: Episode 685.000000. Reward 95.666667. action: 1.000000. mean reward 92.817772.
# World Perf: Episode 688.000000. Reward 132.666667. action: 1.000000. mean reward 93.060539.
# World Perf: Episode 691.000000. Reward 130.666667. action: 1.000000. mean reward 94.697670.
# World Perf: Episode 694.000000. Reward 105.666667. action: 0.000000. mean reward 95.981850.
# World Perf: Episode 697.000000. Reward 116.000000. action: 1.000000. mean reward 95.353142.
# World Perf: Episode 700.000000. Reward 101.666667. action: 1.000000. mean reward 94.764259.
# World Perf: Episode 703.000000. Reward 96.333333. action: 1.000000. mean reward 94.524452.
# World Perf: Episode 706.000000. Reward 132.000000. action: 0.000000. mean reward 94.314545.
# World Perf: Episode 709.000000. Reward 105.666667. action: 0.000000. mean reward 95.659950.
# World Perf: Episode 712.000000. Reward 141.333333. action: 1.000000. mean reward 95.889618.
# World Perf: Episode 715.000000. Reward 163.666667. action: 0.000000. mean reward 98.635109.
# World Perf: Episode 718.000000. Reward 148.666667. action: 1.000000. mean reward 100.246895.
# World Perf: Episode 721.000000. Reward 143.666667. action: 0.000000. mean reward 100.808350.
# World Perf: Episode 724.000000. Reward 49.000000. action: 1.000000. mean reward 102.270638.
# World Perf: Episode 727.000000. Reward 88.333333. action: 1.000000. mean reward 101.260902.
# World Perf: Episode 730.000000. Reward 183.000000. action: 0.000000. mean reward 101.241982.
# World Perf: Episode 733.000000. Reward 118.000000. action: 1.000000. mean reward 101.104530.
# World Perf: Episode 736.000000. Reward 37.333333. action: 1.000000. mean reward 102.032524.
# World Perf: Episode 739.000000. Reward 166.000000. action: 1.000000. mean reward 101.882286.
# World Perf: Episode 742.000000. Reward 127.666667. action: 1.000000. mean reward 101.699455.
# World Perf: Episode 745.000000. Reward 131.000000. action: 1.000000. mean reward 101.745918.
# World Perf: Episode 748.000000. Reward 86.666667. action: 0.000000. mean reward 101.820435.
# World Perf: Episode 751.000000. Reward 102.000000. action: 1.000000. mean reward 101.222923.
# World Perf: Episode 754.000000. Reward 114.666667. action: 1.000000. mean reward 100.536377.
# World Perf: Episode 757.000000. Reward 157.000000. action: 0.000000. mean reward 100.572273.
# World Perf: Episode 760.000000. Reward 115.000000. action: 1.000000. mean reward 101.138481.
# World Perf: Episode 763.000000. Reward 130.000000. action: 1.000000. mean reward 100.536461.
# World Perf: Episode 766.000000. Reward 170.333333. action: 1.000000. mean reward 100.405067.
# World Perf: Episode 769.000000. Reward 200.000000. action: 0.000000. mean reward 100.667549.
# World Perf: Episode 772.000000. Reward 134.666667. action: 1.000000. mean reward 100.260742.
# World Perf: Episode 775.000000. Reward 133.666667. action: 0.000000. mean reward 99.805504.
# World Perf: Episode 778.000000. Reward 174.333333. action: 0.000000. mean reward 99.944824.
# World Perf: Episode 781.000000. Reward 97.000000. action: 1.000000. mean reward 99.740349.
# World Perf: Episode 784.000000. Reward 103.000000. action: 1.000000. mean reward 99.938393.
# World Perf: Episode 787.000000. Reward 145.000000. action: 0.000000. mean reward 99.553650.
# World Perf: Episode 790.000000. Reward 92.333333. action: 1.000000. mean reward 99.156700.
# World Perf: Episode 793.000000. Reward 123.000000. action: 1.000000. mean reward 99.313789.
# World Perf: Episode 796.000000. Reward 187.000000. action: 1.000000. mean reward 100.046143.
# World Perf: Episode 799.000000. Reward 130.333333. action: 1.000000. mean reward 99.670593.
# World Perf: Episode 802.000000. Reward 149.000000. action: 0.000000. mean reward 99.427864.
# World Perf: Episode 805.000000. Reward 95.000000. action: 0.000000. mean reward 98.770821.
# World Perf: Episode 808.000000. Reward 193.000000. action: 0.000000. mean reward 99.170135.
# World Perf: Episode 811.000000. Reward 99.333333. action: 0.000000. mean reward 98.353065.
# World Perf: Episode 814.000000. Reward 184.000000. action: 0.000000. mean reward 98.463562.
# World Perf: Episode 817.000000. Reward 102.000000. action: 1.000000. mean reward 97.849243.
# World Perf: Episode 820.000000. Reward 193.000000. action: 0.000000. mean reward 98.038063.
# World Perf: Episode 823.000000. Reward 149.666667. action: 1.000000. mean reward 97.846748.
# World Perf: Episode 826.000000. Reward 100.666667. action: 0.000000. mean reward 99.787079.
# World Perf: Episode 829.000000. Reward 154.333333. action: 1.000000. mean reward 99.605827.
# World Perf: Episode 832.000000. Reward 200.000000. action: 0.000000. mean reward 100.050629.
# World Perf: Episode 835.000000. Reward 200.000000. action: 0.000000. mean reward 103.092781.
# World Perf: Episode 838.000000. Reward 120.000000. action: 1.000000. mean reward 105.214699.
# World Perf: Episode 841.000000. Reward 104.666667. action: 1.000000. mean reward 106.308708.
# World Perf: Episode 844.000000. Reward 127.333333. action: 1.000000. mean reward 108.388130.
# World Perf: Episode 847.000000. Reward 125.333333. action: 1.000000. mean reward 108.809479.
# World Perf: Episode 850.000000. Reward 200.000000. action: 1.000000. mean reward 110.342964.
# World Perf: Episode 853.000000. Reward 154.333333. action: 1.000000. mean reward 111.856110.
# World Perf: Episode 856.000000. Reward 161.666667. action: 1.000000. mean reward 114.156288.
# World Perf: Episode 859.000000. Reward 76.666667. action: 1.000000. mean reward 112.727600.
# World Perf: Episode 862.000000. Reward 92.000000. action: 1.000000. mean reward 111.905479.
# World Perf: Episode 865.000000. Reward 153.666667. action: 0.000000. mean reward 111.727333.
# World Perf: Episode 868.000000. Reward 196.333333. action: 0.000000. mean reward 111.617699.
# World Perf: Episode 871.000000. Reward 107.333333. action: 0.000000. mean reward 110.565613.
# World Perf: Episode 874.000000. Reward 100.666667. action: 1.000000. mean reward 109.535698.
# World Perf: Episode 877.000000. Reward 168.000000. action: 1.000000. mean reward 109.569649.
# World Perf: Episode 880.000000. Reward 125.666667. action: 0.000000. mean reward 111.538597.
# World Perf: Episode 883.000000. Reward 153.000000. action: 0.000000. mean reward 113.764160.
# World Perf: Episode 886.000000. Reward 164.333333. action: 1.000000. mean reward 115.966827.
# World Perf: Episode 889.000000. Reward 124.000000. action: 1.000000. mean reward 117.031830.
# World Perf: Episode 892.000000. Reward 159.333333. action: 0.000000. mean reward 118.439659.
# World Perf: Episode 895.000000. Reward 169.666667. action: 1.000000. mean reward 118.153725.
# World Perf: Episode 898.000000. Reward 156.333333. action: 1.000000. mean reward 117.640266.
# World Perf: Episode 901.000000. Reward 178.000000. action: 0.000000. mean reward 117.152412.
# World Perf: Episode 904.000000. Reward 146.000000. action: 1.000000. mean reward 116.508919.
# World Perf: Episode 907.000000. Reward 189.333333. action: 0.000000. mean reward 116.654701.
# World Perf: Episode 910.000000. Reward 167.333333. action: 0.000000. mean reward 116.166451.
# World Perf: Episode 913.000000. Reward 179.000000. action: 0.000000. mean reward 115.879181.
# World Perf: Episode 916.000000. Reward 143.666667. action: 1.000000. mean reward 115.407928.
# World Perf: Episode 919.000000. Reward 178.666667. action: 1.000000. mean reward 116.201698.
# World Perf: Episode 922.000000. Reward 180.666667. action: 0.000000. mean reward 117.149109.
# World Perf: Episode 925.000000. Reward 151.333333. action: 1.000000. mean reward 116.837944.
# World Perf: Episode 928.000000. Reward 113.666667. action: 0.000000. mean reward 115.859680.
# World Perf: Episode 931.000000. Reward 126.333333. action: 0.000000. mean reward 115.220985.
# World Perf: Episode 934.000000. Reward 126.000000. action: 1.000000. mean reward 117.421059.
# World Perf: Episode 937.000000. Reward 132.666667. action: 1.000000. mean reward 116.666351.
# World Perf: Episode 940.000000. Reward 149.000000. action: 1.000000. mean reward 118.214050.
# World Perf: Episode 943.000000. Reward 154.666667. action: 1.000000. mean reward 117.690025.
# World Perf: Episode 946.000000. Reward 200.000000. action: 0.000000. mean reward 118.538750.
# World Perf: Episode 949.000000. Reward 147.333333. action: 1.000000. mean reward 120.322304.
# World Perf: Episode 952.000000. Reward 200.000000. action: 1.000000. mean reward 120.066658.
# World Perf: Episode 955.000000. Reward 184.000000. action: 1.000000. mean reward 121.779335.
# World Perf: Episode 958.000000. Reward 170.000000. action: 0.000000. mean reward 124.575958.
# World Perf: Episode 961.000000. Reward 154.666667. action: 1.000000. mean reward 124.849213.
# World Perf: Episode 964.000000. Reward 200.000000. action: 1.000000. mean reward 126.433922.
# World Perf: Episode 967.000000. Reward 143.666667. action: 1.000000. mean reward 127.885681.
# World Perf: Episode 970.000000. Reward 110.333333. action: 1.000000. mean reward 127.894188.
# World Perf: Episode 973.000000. Reward 200.000000. action: 1.000000. mean reward 128.657043.
# World Perf: Episode 976.000000. Reward 160.000000. action: 0.000000. mean reward 130.650833.
# World Perf: Episode 979.000000. Reward 200.000000. action: 1.000000. mean reward 130.603561.
# World Perf: Episode 982.000000. Reward 185.333333. action: 1.000000. mean reward 130.153946.
# World Perf: Episode 985.000000. Reward 200.000000. action: 1.000000. mean reward 132.707077.
# World Perf: Episode 988.000000. Reward 174.666667. action: 1.000000. mean reward 133.941483.
# World Perf: Episode 991.000000. Reward 176.666667. action: 0.000000. mean reward 133.358002.
# World Perf: Episode 994.000000. Reward 179.666667. action: 1.000000. mean reward 135.494949.
# World Perf: Episode 997.000000. Reward 171.333333. action: 0.000000. mean reward 135.632416.
# World Perf: Episode 1000.000000. Reward 200.000000. action: 1.000000. mean reward 135.085556.
# World Perf: Episode 1003.000000. Reward 200.000000. action: 1.000000. mean reward 137.406113.
# World Perf: Episode 1006.000000. Reward 200.000000. action: 1.000000. mean reward 139.741608.
# World Perf: Episode 1009.000000. Reward 195.000000. action: 0.000000. mean reward 139.328110.
# World Perf: Episode 1012.000000. Reward 166.000000. action: 0.000000. mean reward 139.474396.
# World Perf: Episode 1015.000000. Reward 200.000000. action: 1.000000. mean reward 140.283157.
# World Perf: Episode 1018.000000. Reward 163.000000. action: 1.000000. mean reward 140.880051.
# World Perf: Episode 1021.000000. Reward 200.000000. action: 0.000000. mean reward 140.835815.
# World Perf: Episode 1024.000000. Reward 176.666667. action: 1.000000. mean reward 140.352554.
# World Perf: Episode 1027.000000. Reward 164.666667. action: 1.000000. mean reward 142.176056.
# World Perf: Episode 1030.000000. Reward 172.333333. action: 1.000000. mean reward 144.047379.
# World Perf: Episode 1033.000000. Reward 179.666667. action: 1.000000. mean reward 144.197952.
# World Perf: Episode 1036.000000. Reward 182.333333. action: 1.000000. mean reward 144.481033.
# World Perf: Episode 1039.000000. Reward 200.000000. action: 1.000000. mean reward 145.993729.
# World Perf: Episode 1042.000000. Reward 179.333333. action: 0.000000. mean reward 146.984924.
# World Perf: Episode 1045.000000. Reward 168.333333. action: 0.000000. mean reward 145.945251.
# World Perf: Episode 1048.000000. Reward 188.000000. action: 1.000000. mean reward 147.970230.
# World Perf: Episode 1051.000000. Reward 198.333333. action: 0.000000. mean reward 147.594666.
# World Perf: Episode 1054.000000. Reward 154.333333. action: 1.000000. mean reward 149.172409.
# World Perf: Episode 1057.000000. Reward 200.000000. action: 1.000000. mean reward 148.421249.
# World Perf: Episode 1060.000000. Reward 200.000000. action: 1.000000. mean reward 148.770157.
# World Perf: Episode 1063.000000. Reward 128.333333. action: 1.000000. mean reward 147.742813.
# World Perf: Episode 1066.000000. Reward 200.000000. action: 0.000000. mean reward 148.737503.
# World Perf: Episode 1069.000000. Reward 200.000000. action: 0.000000. mean reward 149.253281.
# World Perf: Episode 1072.000000. Reward 184.333333. action: 1.000000. mean reward 151.049957.
# World Perf: Episode 1075.000000. Reward 163.333333. action: 0.000000. mean reward 152.052063.
# World Perf: Episode 1078.000000. Reward 200.000000. action: 0.000000. mean reward 151.676620.
# World Perf: Episode 1081.000000. Reward 200.000000. action: 1.000000. mean reward 151.639633.
# World Perf: Episode 1084.000000. Reward 192.000000. action: 0.000000. mean reward 150.922806.
# World Perf: Episode 1087.000000. Reward 200.000000. action: 0.000000. mean reward 150.394485.
# World Perf: Episode 1090.000000. Reward 200.000000. action: 0.000000. mean reward 152.444717.
# World Perf: Episode 1093.000000. Reward 200.000000. action: 1.000000. mean reward 153.639267.
# World Perf: Episode 1096.000000. Reward 200.000000. action: 0.000000. mean reward 155.585068.
# World Perf: Episode 1099.000000. Reward 200.000000. action: 1.000000. mean reward 156.029022.
# World Perf: Episode 1102.000000. Reward 200.000000. action: 1.000000. mean reward 155.207153.
# World Perf: Episode 1105.000000. Reward 200.000000. action: 0.000000. mean reward 155.065903.
# World Perf: Episode 1108.000000. Reward 185.666667. action: 1.000000. mean reward 154.169266.
# World Perf: Episode 1111.000000. Reward 181.333333. action: 1.000000. mean reward 153.591614.
# World Perf: Episode 1114.000000. Reward 196.666667. action: 0.000000. mean reward 154.713608.
# World Perf: Episode 1117.000000. Reward 200.000000. action: 0.000000. mean reward 154.797409.
# World Perf: Episode 1120.000000. Reward 159.666667. action: 0.000000. mean reward 153.849442.
# World Perf: Episode 1123.000000. Reward 199.000000. action: 0.000000. mean reward 155.895676.
# World Perf: Episode 1126.000000. Reward 191.000000. action: 1.000000. mean reward 157.700424.
# World Perf: Episode 1129.000000. Reward 153.000000. action: 1.000000. mean reward 156.585327.
# World Perf: Episode 1132.000000. Reward 200.000000. action: 0.000000. mean reward 158.482681.
# World Perf: Episode 1135.000000. Reward 178.333333. action: 1.000000. mean reward 160.108932.
# World Perf: Episode 1138.000000. Reward 166.000000. action: 1.000000. mean reward 159.419846.
# World Perf: Episode 1141.000000. Reward 200.000000. action: 0.000000. mean reward 159.278214.
# World Perf: Episode 1144.000000. Reward 149.000000. action: 0.000000. mean reward 160.261337.
# World Perf: Episode 1147.000000. Reward 200.000000. action: 0.000000. mean reward 161.582870.
# World Perf: Episode 1150.000000. Reward 183.666667. action: 1.000000. mean reward 163.200821.
# World Perf: Episode 1153.000000. Reward 182.333333. action: 0.000000. mean reward 162.574844.
# World Perf: Episode 1156.000000. Reward 200.000000. action: 0.000000. mean reward 162.732239.
# World Perf: Episode 1159.000000. Reward 177.666667. action: 1.000000. mean reward 163.348160.
# World Perf: Episode 1162.000000. Reward 146.000000. action: 0.000000. mean reward 161.792297.
# World Perf: Episode 1165.000000. Reward 200.000000. action: 1.000000. mean reward 163.671692.
# World Perf: Episode 1168.000000. Reward 143.000000. action: 0.000000. mean reward 164.782333.
# World Perf: Episode 1171.000000. Reward 168.333333. action: 0.000000. mean reward 163.306107.
# World Perf: Episode 1174.000000. Reward 176.333333. action: 0.000000. mean reward 162.057907.
# World Perf: Episode 1177.000000. Reward 159.666667. action: 1.000000. mean reward 163.478653.
# World Perf: Episode 1180.000000. Reward 160.000000. action: 1.000000. mean reward 161.935150.
# World Perf: Episode 1183.000000. Reward 200.000000. action: 1.000000. mean reward 161.052368.
# World Perf: Episode 1186.000000. Reward 197.666667. action: 1.000000. mean reward 161.635422.
# World Perf: Episode 1189.000000. Reward 168.666667. action: 0.000000. mean reward 163.047943.
# World Perf: Episode 1192.000000. Reward 164.333333. action: 1.000000. mean reward 164.362686.
# World Perf: Episode 1195.000000. Reward 194.333333. action: 0.000000. mean reward 163.232498.
# World Perf: Episode 1198.000000. Reward 200.000000. action: 1.000000. mean reward 162.119049.
# World Perf: Episode 1201.000000. Reward 195.666667. action: 1.000000. mean reward 163.778305.
# World Perf: Episode 1204.000000. Reward 189.666667. action: 1.000000. mean reward 163.541519.
# World Perf: Episode 1207.000000. Reward 187.000000. action: 0.000000. mean reward 162.265015.
# World Perf: Episode 1210.000000. Reward 191.333333. action: 1.000000. mean reward 163.399338.
# World Perf: Episode 1213.000000. Reward 200.000000. action: 0.000000. mean reward 165.220444.
# World Perf: Episode 1216.000000. Reward 200.000000. action: 1.000000. mean reward 164.113419.
# World Perf: Episode 1219.000000. Reward 136.666667. action: 1.000000. mean reward 165.169144.
# World Perf: Episode 1222.000000. Reward 168.666667. action: 0.000000. mean reward 163.900848.
# World Perf: Episode 1225.000000. Reward 168.666667. action: 0.000000. mean reward 162.632370.
# World Perf: Episode 1228.000000. Reward 200.000000. action: 0.000000. mean reward 161.481918.
# World Perf: Episode 1231.000000. Reward 200.000000. action: 1.000000. mean reward 161.775894.
# World Perf: Episode 1234.000000. Reward 200.000000. action: 1.000000. mean reward 163.582367.
# World Perf: Episode 1237.000000. Reward 200.000000. action: 1.000000. mean reward 162.483017.
# World Perf: Episode 1240.000000. Reward 200.000000. action: 1.000000. mean reward 161.627258.
# World Perf: Episode 1243.000000. Reward 183.666667. action: 1.000000. mean reward 163.254715.
# World Perf: Episode 1246.000000. Reward 200.000000. action: 1.000000. mean reward 162.447540.
# World Perf: Episode 1249.000000. Reward 195.333333. action: 1.000000. mean reward 161.987808.
# World Perf: Episode 1252.000000. Reward 198.333333. action: 0.000000. mean reward 160.922974.
# World Perf: Episode 1255.000000. Reward 200.000000. action: 1.000000. mean reward 159.873703.
# World Perf: Episode 1258.000000. Reward 200.000000. action: 1.000000. mean reward 159.939407.
# World Perf: Episode 1261.000000. Reward 200.000000. action: 0.000000. mean reward 160.326370.
# World Perf: Episode 1264.000000. Reward 189.000000. action: 1.000000. mean reward 161.561829.
# World Perf: Episode 1267.000000. Reward 188.000000. action: 0.000000. mean reward 163.172836.
# World Perf: Episode 1270.000000. Reward 200.000000. action: 1.000000. mean reward 163.070450.
# World Perf: Episode 1273.000000. Reward 200.000000. action: 0.000000. mean reward 163.117264.
# World Perf: Episode 1276.000000. Reward 190.666667. action: 0.000000. mean reward 164.680618.
# World Perf: Episode 1279.000000. Reward 189.333333. action: 1.000000. mean reward 164.905441.
# World Perf: Episode 1282.000000. Reward 200.000000. action: 1.000000. mean reward 166.586105.
# World Perf: Episode 1285.000000. Reward 200.000000. action: 1.000000. mean reward 168.425964.
# World Perf: Episode 1288.000000. Reward 200.000000. action: 1.000000. mean reward 168.080002.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-df67beea51f1> in <module>()
#      24         # Start displaying environment once performance is acceptably high.
#      25         if (reward_sum/batch_size > 150 and drawFromModel == False) or rendering == True :
# ---> 26             env.render()
#      27             rendering = True
#      28
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\gym\core.py in render(self, mode)
#     282
#     283     def render(self, mode='human'):
# --> 284         return self.env.render(mode)
#     285
#     286     def close(self):
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\gym\envs\classic_control\cartpole.py in render(self, mode)
#     135         self.poletrans.set_rotation(-x[2])
#     136
# --> 137         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#     138
#     139     def close(self):
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\gym\envs\classic_control\rendering.py in render(self, return_rgb_array)
#     103             arr = arr.reshape(buffer.height, buffer.width, 4)
#     104             arr = arr[::-1,:,0:3]
# --> 105         self.window.flip()
#     106         self.onetime_geoms = []
#     107         return arr if return_rgb_array else self.isopen
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\pyglet\window\win32\__init__.py in flip(self)
#     309     def flip(self):
#     310         self.draw_mouse_cursor()
# --> 311         self.context.flip()
#     312
#     313     def set_location(self, x, y):
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\pyglet\gl\win32.py in flip(self)
#     222
#     223     def flip(self):
# --> 224         wgl.wglSwapLayerBuffers(self.canvas.hdc, wgl.WGL_SWAP_MAIN_PLANE)
#     225
#     226     def get_vsync(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Checking model representation
# Here we can examine how well the model is able to approximate the true environment after training. The green line indicates the real environment, and the blue indicates model predictions.

# %%
plt.figure(figsize=(8, 12))
for i in range(6):
    plt.subplot(6, 2, 2*i + 1)
    plt.plot(pState[:,i])   # draw the model predictions
    plt.subplot(6,2,2*i+1)
 
   
    ################################################################################
    # TODO: draw the real environment for comparison                               #
    ################################################################################
    plt.plot(state_nextsAll[:,i])
    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################
plt.tight_layout()
